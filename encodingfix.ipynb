# %%
import os
import shutil
import simpledbf

# %%
os.getcwd()

# %%
# zouska na testovacich datech
walk = os.walk("data_test/dbf", followlinks=0)
files = []


def convertdbftocsv(file):
    codecs = ("cp852","cp437","utf-8","cp1250")
    for codec in codecs:
        try:
            dbf = simpledbf.Dbf5(file, codec=codec)
            csv = file + "." + codec + ".csv"
            #print(file, "coverted to", csv)
            if codec != 'utf-8':
                fixencoding(csv,codec)
        except BaseException as err:
            print("dbftocsv",file, err, "with", codec)



def fixencoding(file,code):
    text = ""
    backup = file + "." + code + ".bak"
    try:
        with open(file, 'r', encoding=code) as f:
            text = f.read()
        try:
            shutil.copy(file,backup)
            print("writing backup file:", backup)
        except BaseException as err:
            print("error writing backup file", err, backup)

        with open(file, 'w', encoding='utf8') as fb:
            fb.write(text)
            print("\t",file, "converting from", code, "into utf-8:", file)
    except BaseException as err:
        print("\tfixencoding:", file, err)

def main():
    for a, b, c in walk:
        for j in c:
            # print(j)
            f = os.path.join(a,j)
            files.append(f)
    for datafile in files:
        _, filetype = datafile.rsplit(".", maxsplit=1)
        filetype = filetype.lower()
        if ("csv" or "xml" or "xsd") in filetype:
            try:
                with open(datafile,'r') as f:
                    f.read()
            except UnicodeDecodeError as unierr:
                print("main:", file, unierr)
                fixencoding(datafile)
        elif "dbf" in filetype:
            print(file)
            convertdbftocsv(datafile)
        # match filetype:
        #     case "bak":
        #         continue
        #     case "dbf":
        #         convertdbftocsv(datafile)
        #     case "csv" | "xml" | "xsd":
        #         try:
        #             with open(datafile,'r') as f:
        #                 text = f.read()
        #                 #print(jsonText)
        #         except UnicodeDecodeError:
        #             fixencoding(datafile)


main()
# Out:
# data_test/.ipynb_checkpoints/dbf2csvtest-checkpoint.csv
# 	fixencoding: data_test/ps2006/PS2006reg2006/PSRK.dbf.cp852.csv [Errno 2] No such file or directory: 'data_test/ps2006/PS2006reg2006/PSRK.dbf.cp852.csv'
# 	fixencoding: data_test/ps2006/PS2006reg2006/PSRK.dbf.cp437.csv [Errno 2] No such file or directory: 'data_test/ps2006/PS2006reg2006/PSRK.dbf.cp437.csv'
# 	fixencoding: data_test/ps2006/PS2006reg2006/PSRK.dbf.cp1250.csv [Errno 2] No such file or directory: 'data_test/ps2006/PS2006reg2006/PSRK.dbf.cp1250.csv'
# data_test/.ipynb_checkpoints/dbf2csvtest-checkpoint.csv
# 	fixencoding: data_test/ps2006/PS2006reg2006/PSRKL.dbf.cp852.csv [Errno 2] No such file or directory: 'data_test/ps2006/PS2006reg2006/PSRKL.dbf.cp852.csv'
# 	fixencoding: data_test/ps2006/PS2006reg2006/PSRKL.dbf.cp437.csv [Errno 2] No such file or directory: 'data_test/ps2006/PS2006reg2006/PSRKL.dbf.cp437.csv'
# 	fixencoding: data_test/ps2006/PS2006reg2006/PSRKL.dbf.cp1250.csv [Errno 2] No such file or directory: 'data_test/ps2006/PS2006reg2006/PSRKL.dbf.cp1250.csv'
# data_test/.ipynb_checkpoints/dbf2csvtest-checkpoint.csv
# 	fixencoding: data_test/ps2006/PS2006_data_dbf/PST4p.dbf.cp852.csv [Errno 2] No such file or directory: 'data_test/ps2006/PS2006_data_dbf/PST4p.dbf.cp852.csv'
# 	fixencoding: data_test/ps2006/PS2006_data_dbf/PST4p.dbf.cp437.csv [Errno 2] No such file or directory: 'data_test/ps2006/PS2006_data_dbf/PST4p.dbf.cp437.csv'
# 	fixencoding: data_test/ps2006/PS2006_data_dbf/PST4p.dbf.cp1250.csv [Errno 2] No such file or directory: 'data_test/ps2006/PS2006_data_dbf/PST4p.dbf.cp1250.csv'
# data_test/.ipynb_checkpoints/dbf2csvtest-checkpoint.csv
# 	fixencoding: data_test/ps2006/PS2006_data_dbf/PST4.dbf.cp852.csv [Errno 2] No such file or directory: 'data_test/ps2006/PS2006_data_dbf/PST4.dbf.cp852.csv'
# 	fixencoding: data_test/ps2006/PS2006_data_dbf/PST4.dbf.cp437.csv [Errno 2] No such file or directory: 'data_test/ps2006/PS2006_data_dbf/PST4.dbf.cp437.csv'
# 	fixencoding: data_test/ps2006/PS2006_data_dbf/PST4.dbf.cp1250.csv [Errno 2] No such file or directory: 'data_test/ps2006/PS2006_data_dbf/PST4.dbf.cp1250.csv'
# data_test/.ipynb_checkpoints/dbf2csvtest-checkpoint.csv
# 	fixencoding: data_test/ps2006/PS2006ciselniky2006/PSCOCO.DBF.cp852.csv [Errno 2] No such file or directory: 'data_test/ps
cp852.csv [Errno 2] No such file or directory: 'data_test/ps2013/ps2013_dbf_20131026/PSRK.dbf.cp852.csv'
# 	fixencoding: data_test/ps2013/ps2013_dbf_20131026/PSRK.dbf.cp437.csv [Errno 2] No such file or directory: 'data_test/ps2013/ps2013_dbf_20131026/PSRK.dbf.cp437.csv'
# 	fixencoding: data_test/ps2013/ps2013_dbf_20131026/PSRK.dbf.cp1250.csv [Errno 2] No such file or directory: 'data_test/ps2013/ps2013_dbf_20131026/PSRK.dbf.cp1250.csv'
# data_test/.ipynb_checkpoints/dbf2csvtest-checkpoint.csv
# 	fixencoding: data_test/ps2013/ps2013_dbf_20131026/PSRKL.dbf.cp852.csv [Errno 2] No such file or directory: 'data_test/ps2013/ps2013_dbf_20131026/PSRKL.dbf.cp852.csv'
# 	fixencoding: data_test/ps2013/ps2013_dbf_20131026/PSRKL.dbf.cp437.csv [Errno 2] No such file or directory: 'data_test/ps2013/ps2013_dbf_20131026/PSRKL.dbf.cp437.csv'
# 	fixencoding: data_test/ps2013/ps2013_dbf_20131026/PSRKL.dbf.cp1250.csv [Errno 2] No such file or directory: 'data_test/ps2013/ps2013_dbf_20131026/PSRKL.dbf.cp1250.csv'
# data_test/.ipynb_checkpoints/dbf2csvtest-checkpoint.csv
# 	fixencoding: data_test/ps2013/ps2013_dbf_20131026/PST4.dbf.cp852.csv [Errno 2] No such file or directory: 'data_test/ps2013/ps2013_dbf_20131026/PST4.dbf.cp852.csv'
# 	fixencoding: data_test/ps2013/ps2013_dbf_20131026/PST4.dbf.cp437.csv [Errno 2] No such file or directory: 'data_test/ps2013/ps2013_dbf_20131026/PST4.dbf.cp437.csv'
# 	fixencoding: data_test/ps2013/ps2013_dbf_20131026/PST4.dbf.cp1250.csv [Errno 2] No such file or directory: 'data_test/ps2013/ps2013_dbf_20131026/PST4.dbf.cp1250.csv'
# data_test/.ipynb_checkpoints/dbf2csvtest-checkpoint.csv
# 	fixencoding: data_test/ps2013/ps2013_dbf_20131026/PST4p.dbf.cp852.csv [Errno 2] No such file or directory: 'data_test/ps2013/ps2013_dbf_20131026/PST4p.dbf.cp852.csv'
# 	fixencoding: data_test/ps2013/ps2013_dbf_20131026/PST4p.dbf.cp437.csv [Errno 2] No such file or directory: 'data_test/ps2013/ps2013_dbf_20131026/PST4p.dbf.cp437.csv'
# 	fixencoding: data_test/ps2013/ps2013_dbf_20131026/PST4p.dbf.cp1250.csv [Errno 2] No such file or directory: 'data_test/ps2013/ps2013_dbf_20131026/PST4p.dbf.cp1250.csv'

# %%
walk
# Out:
# <generator object _walk at 0x7f3a719bb370>

# %%
os.listdir(r)
# Out:
# ['pst4.json',
#  'pst4p cp1250.json',
#  'pst4p_utf8.json',
#  'pst4.csv',
#  'pst4p.csv',
#  'pst4p.json',
#  'testtest',
#  '{}.bak']

# %%
with open('pst4p cp1250.json',
      #    encoding="cp1250"
         ) as f:
    text = f.read()
    print(text)
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In [16], line 4
#       1 with open('pst4p cp1250.json',
#       2       #    encoding="cp1250"
#       3          ) as f:
# ----> 4     text = f.read()
#       5     print(text)
#
# File ~/.conda/envs/volby/lib/python3.10/codecs.py:322, in BufferedIncrementalDecoder.decode(self, input, final)
#     319 def decode(self, input, final=False):
#     320     # decode input (taking the buffer into account)
#     321     data = self.buffer + input
# --> 322     (result, consumed) = self._buffer_decode(data, self.errors, final)
#     323     # keep undecoded input until the next call
#     324     self.buffer = data[consumed:]
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xe1 in position 131: invalid continuation byte

# %%
f.readlines()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [10], line 1
# ----> 1 f.readlines()
#
# ValueError: I/O operation on closed file.

# %%
with open ('pst4p.json'
          # , encoding="cp1250"
          ) as file:
    text = file.read()
    print(text)
# Out:
# {
#   "@context": ["http://www.w3.org/ns/csvw",{"@language": "cs"}],
#   "url": "pst4p.csv",
#   "dc:description": "Data z přílohy č. 1 k tiskopisu T/4 zápisu komise v kompletní podobě (široká struktura)",
#   "tableSchema": {
#     "columns": [{
#       "name": "ID_OKRSKY",
#       "titles": "ID_OKRSKY",
#       "dc:description": "Odkaz na identifikaci okrsku (FK)",
#       "required": false,
#       "datatype": "number"
#     },{
#       "name": "TYP_FORM",
#       "titles": "TYP_FORM",
#       "dc:description": "Obsah dat ve větě (1 = T/4, 2 = příloha T/4, 3 = součtová věta TS)",
#       "required": true,
#       "datatype": "number"
#     },{
#       "name": "OPRAVA",
#       "titles": "OPRAVA",
#       "dc:description": "Příznak dodatečné opravy na přebíracím místě v případě chyby (1 = opraven, 0 = neopraven)",
#       "required": true,
#       "datatype": "number"
#     },{
#       "name": "CHYBA",
#       "titles": "CHYBA",
#       "dc:description": "Příznak chyby (pustitelné) v datech (1 = je chyba, 0 = není chyba)",
#       "required": true,
#       "datatype": "number"
#     },{
#       "name": "OKRES",
#       "titles": "OKRES",
#       "dc:description": "Kód okresu dle CNUMNUTS",
#       "required": true,
#       "datatype": "number"
#     },{
#       "name": "OBEC",
#       "titles": "OBEC",
#       "dc:description": "Kód obce dle COCO",
#       "required": true,
#       "datatype": "number"
#     },{
#       "name": "OKRSEK",
#       "titles": "OKRSEK",
#       "dc:description": "Číslo okrsku v rámci obce",
#       "required": true,
#       "datatype": "number"
#     },{
#       "name": "KC_1",
#       "titles": "KC_1",
#       "dc:description": "Kontrolní číslo 1 (MODULO7)",
#       "required": true,
#       "datatype": "number"
#     },{
#       "name": "KSTRANA",
#       "titles": "KSTRANA",
#       "dc:description": "Vylosované číslo strany",
#       "required": false,
#       "datatype": "number"
#     },{
#       "name": "POC_HLASU",
#       "titles": "POC_HLASU",
#       "dc:description": "Počet platných hlasů pro stranu",
#       "required": true,
#       "datatype": "number"
#     },{
#       "name": "KC_2",
#       "titles": "KC_2",
#       "dc:description": "Kontrolní číslo 2",
#       "required": true,
#       "datatype": "number"
#     },{
#       "name": "HLASY_01",
#       "titles": "HLASY_01",
#       "dc:description": "Počet přednostních hlasů pro kandidáta s pořadovým číslem 1",
#       "required": true,
#       "datatype": "number"
#     },{
#       "name": "HLASY_02",
#       "titles": "HLASY_02",
#       "dc:description": "Počet přednostních hlasů pro kandidáta s pořadovým číslem 2",
#       "required": true,
#       "datatype": "number"
#     },{
#       "name": "HLASY_03",
#       "titles": "HLASY_03",
#       "dc:description": "Počet přednostních hlasů pro kandidáta s pořadovým číslem 3",
#       "required": true,
#       "datatype": "number"
#     },{
#       "name": "HLASY_04",
#       "titles": "HLASY_04",
#       "dc:description": "Počet přednostních hlasů pro kandidáta s pořadovým číslem 4",
#       "required": true,
#       "datatype": "number"
#     },{
#       "name": "HLASY_05",
#       "titles": "HLASY_05",
#       "dc:description": "Počet přednostních hlasů pro kandidáta s pořadovým číslem 5",
#       "required": true,
#       "datatype": "number"
#     },{
#       "name": "HLASY_06",
#       "titles": "HLASY_06",
#       "dc:description": "Počet přednostních hlasů pro kandidáta s pořadovým číslem 6",
#       "required": true,
#       "datatype": "number"
#     },{
#       "name": "HLASY_07",
#       "titles": "HLASY_07",
#       "dc:description": "Počet přednostních hlasů pro kandidáta s pořadovým číslem 7",
#       "required": true,
#       "datatype": "number"
#     },{
#       "name": "HLASY_08",
#       "titles": "HLASY_08",
#       "dc:description": "Počet přednostních hlasů pro kandidáta s pořadovým číslem 8",
#       "required": true,
#       "datatype": "number"
#     },{
#       "name": "HLASY_09",
#       "titles": "HLASY_09",
#       "dc:description": "Počet přednostních hlasů pro kandidáta s pořadovým číslem 9",
#       "required": true,
#       "datatype": "number"
#     },{
#       "name": "HLASY_10",
#       "titles": "HLASY_10",
#       "dc:description": "Počet přednostních hlasů pro kandidáta s pořadovým číslem 10",
#       "required": true,
#       "datatype": "number"
#     },{
#       "name": "HLASY_11",
#       "titles": "HLASY_11",
#       "dc:description": "Počet přednostních hlasů pro kandidáta s pořadovým číslem 11",
#       "required": true,
#       "datatype": "number"
#     },{
#       "name": "HLASY_12",
#       "titles": "HLASY_12",
#       "dc:description": "Počet přednostních hlasů pro kandidáta s pořadovým číslem 12",
#       "required": true,
#       "datatype": "number"
#     },{
#       "name": "HLASY_13",
#       "titles": "HLASY_13",
#       "dc:description": "Počet přednostních hlasů pro kandidáta s pořadovým číslem 13",
#       "required": true,
#       "datatype": "number"
#     },{
#       "name": "HLASY_14",
#       "titles": "HLASY_14",
#       "dc:description": "Počet přednostních hlasů pro kandidáta s pořadovým číslem 14",
#       "required": true,
#       "datatype": "number"
#     },{
#       "name": "HLASY_15",
#       "titles": "HLASY_15",
#       "dc:description": "Počet přednostních hlasů pro kandidáta s pořadovým číslem 15",
#       "required": true,
#       "datatype": "number"
#     },{
#       "name": "HLASY_16",
#       "titles": "HLASY_16",
#       "dc:description": "Počet přednostních hlasů pro kandidáta s pořadovým číslem 16",
#       "required": true,
#       "datatype": "number"
#     },{
#       "name": "HLASY_17",
#       "titles": "HLASY_17",
#       "dc:description": "Počet přednostních hlasů pro kandidáta s pořadovým číslem 17",
#       "required": true,
#       "datatype": "number"
#     },{
#       "name": "HLASY_18",
#       "titles": "HLASY_18",
#       "dc:description": "Počet přednostních hlasů pro kandidáta s pořadovým číslem 18",
#       "required": true,
#       "datatype": "number"
#     },{
#       "name": "HLASY_19",
#       "titles": "HLASY_19",
#       "dc:description": "Počet přednostních hlasů pro kandidáta s pořadovým číslem 19",
#       "required": true,
#       "datatype": "number"
#     },{
#       "name": "HLASY_20",
#       "titles": "HLASY_20",
#       "dc:description": "Počet přednostních hlasů pro kandidáta s pořadovým číslem 20",
#       "required": true,
#       "datatype": "number"
#     },{
#       "name": "HLASY_21",
#       "titles": "HLASY_21",
#       "dc:description": "Počet přednostních hlasů pro kandidáta s pořadovým číslem 21",
#       "required": true,
#       "datatype": "number"
#     },{
#       "name": "HLASY_22",
#       "titles": "HLASY_22",
#       "dc:description": "Počet přednostních hlasů pro kandidáta s pořadovým číslem 22",
#       "required": true,
#       "datatype": "number"
#     },{
#       "name": "HLASY_23",
#       "titles": "HLASY_23",
#       "dc:description": "Počet přednostních hlasů pro kandidáta s pořadovým číslem 23",
#       "required": true,
#       "datatype": "number"
#     },{
#       "name": "HLASY_24",
#       "titles": "HLASY_24",
#       "dc:description": "Počet přednostních hlasů pro kandidáta s pořadovým číslem 24",
#       "required": true,
#       "datatype": "number"
#     },{
#       "name": "HLASY_25",
#       "titles": "HLASY_25",
#       "dc:description": "Počet přednostních hlasů pro kandidáta s pořadovým číslem 25",
#       "required": true,
#       "datatype": "number"
#     },{
#       "name": "HLASY_26",
#       "titles": "HLASY_26",
#       "dc:description": "Počet přednostních hlasů pro kandidáta s pořadovým číslem 26",
#       "required": true,
#       "datatype": "number"
#     },{
#       "name": "HLASY_27",
#       "titles": "HLASY_27",
#       "dc:description": "Počet přednostních hlasů pro kandidáta s pořadovým číslem 27",
#       "required": true,
#       "datatype": "number"
#     },{
#       "name": "HLASY_28",
#       "titles": "HLASY_28",
#       "dc:description": "Počet přednostních hlasů pro kandidáta s pořadovým číslem 28",
#       "required": true,
#       "datatype": "number"
#     },{
#       "name": "HLASY_29",
#       "titles": "HLASY_29",
#       "dc:description": "Počet přednostních hlasů pro kandidáta s pořadovým číslem 29",
#       "required": true,
#       "datatype": "number"
#     },{
#       "name": "HLASY_30",
#       "titles": "HLASY_30",
#       "dc:description": "Počet přednostních hlasů pro kandidáta s pořadovým číslem 30",
#       "required": true,
#       "datatype": "number"
#     },{
#       "name": "HLASY_31",
#       "titles": "HLASY_31",
#       "dc:description": "Počet přednostních hlasů pro kandidáta s pořadovým číslem 31",
#       "required": true,
#       "datatype": "number"
#     },{
#       "name": "HLASY_32",
#       "titles": "HLASY_32",
#       "dc:description": "Počet přednostních hlasů pro kandidáta s pořadovým číslem 32",
#       "required": true,
#       "datatype": "number"
#     },{
#       "name": "HLASY_33",
#       "titles": "HLASY_33",
#       "dc:description": "Počet přednostních hlasů pro kandidáta s pořadovým číslem 33",
#       "required": true,
#       "datatype": "number"
#     },{
#       "name": "HLASY_34",
#       "titles": "HLASY_34",
#       "dc:description": "Počet přednostních hlasů pro kandidáta s pořadovým číslem 34",
#       "required": true,
#       "datatype": "number"
#     },{
#       "name": "HLASY_35",
#       "titles": "HLASY_35",
#       "dc:description": "Počet přednostních hlasů pro kandidáta s pořadovým číslem 35",
#       "required": true,
#       "datatype": "number"
#     },{
#       "name": "HLASY_36",
#       "titles": "HLASY_36",
#       "dc:description": "Počet přednostních hlasů pro kandidáta s pořadovým číslem 36",
#       "required": true,
#       "datatype": "number"
#     },{
#       "name": "KC_3",
#       "titles": "KC_3",
#       "dc:description": "Kontrolní číslo 3",
#       "required": true,
#       "datatype": "number"
#     },{
#       "name": "KC_4",
#       "titles": "KC_4",
#       "dc:description": "Kontrolní číslo 4 ",
#       "required": true,
#       "datatype": "number"
#     },{
#       "name": "POSL_KAND",
#       "titles": "POSL_KAND",
#       "dc:description": "Poslední číslo kandidáta strany, který získal přednostní hlasy",
#       "required": true,
#       "datatype": "number"
#     },{
#       "name": "KC_SUM",
#       "titles": "KC_SUM",
#       "dc:description": "Sumární kontrolní číslo přílohy T4",
#       "required": true,
#       "datatype": "number"
#     }
#     ],
#     "primaryKey": ["ID_OKRSKY","KSTRANA"]
#   }
# }
